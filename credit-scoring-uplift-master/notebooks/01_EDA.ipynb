# %%
import pandas as pd

# %%
# Out:
#   Cell In[6], line 1
#     df = pd.read_csv('C:\Users\pc\Downloads\credit-scoring-uplift-master\credit-scoring-uplift-master\data\accepted_2007_to_2018q4.csv\accepted_2007_to_2018Q4.csv', encoding='UTF-8')
#                      ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape
